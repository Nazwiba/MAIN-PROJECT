# %% [markdown]
# ## 📋 Project Title:
# # SHOPPING BEHAVIOUR DATA ANALYSIS USING PYTHON

# %% [markdown]
# ## 1️⃣. OBJECTIVE :
#
# This dataset contains detailed information about customer demographics and shopping behavior. It includes attributes such as gender, age group, time period income, and spending score, providing insights into how consumer characteristics influence purchasing decisions. The data can be used for market sectionalization, consumer trend analysis, and retail strategy improvement.By using Python libraries such as Pandas, Numpy,Matplotlib, Seaborn, Using these libraries we perform data cleaning, preprocessing, Exploratory data Analysis, and visualization to derive valuable insights.
# Domain: Retail (Customer Purchasing Pattern)
# Dataset: Customer Shopping Behaviour (Kaggle)

# %% [markdown]
# ## 2️⃣. TOOLS & LIBRARIES USED :
#     1. Pandas  -  data cleaning & manipulation
#     2. Matplotlib / seaborn  - visualization
#     3. Numpy  -  numerical computation

# %% [markdown]
# ## 3️⃣. DATASET OVERVIEW :
#
#     File name: SHOPPING_BEHAVIOUR.csv
#     Number of records: 3899
#     Number of columns: 17

# %% [markdown]
# ## 4️⃣. IMPORT LIBRARIES :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Libraries are imported successfully!!
#
# we use Libraries like Pandas and numpy for data cleaning and preprocessing
# matplotlib and seaborn is used for data visualization.

# %% [markdown]
# ## 5️⃣. LOAD DATA SET :

# %%
# Load csv file
df = pd.read_csv("SHOPPING_BEHAVIOUR.csv")
print("Load Dataset Successfully")
df
# Out:
# Load Dataset Successfully
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# ## 6️⃣. INITIAL DATA OVERVIEW:
#     6.1 Initial Overview
#     6.2 Description of data
#     6.3 Number of rows and columns
#     6.4 Datatypes of each column

# %% [markdown]
# ### 6.1 Initial Overview

# %%
# Initial Observation
print("Info of dataset")
df.info()
# Out:
# Info of dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %% [markdown]
# df.info() is a DataFrame method in the Python Pandas library that provides a concise summary of the DataFrame — including its index, column names, data types, non-null values, and memory usage.

# %%
print("First 5 rows")
df.head()
# Out:
# First 5 rows
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# df.head() is a Pandas DataFrame method used to display the first few rows of a DataFrame — by default, the first 5 rows.

# %%
print("Last 5 Rows")
df.tail()
# Out:
# Last 5 Rows
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 3895            4.2                  No  2-Day Shipping               No
# ...

# %% [markdown]
# df.tail() is a Pandas DataFrame method used to display the last few rows of a DataFrame — by default, the last 5 rows.

# %% [markdown]
# ### 6.2 Description of Data

# %%
print("\nDescriptive statistics for numerical column:")
df.describe()
# Out:
# Descriptive statistics for numerical column:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# df.describe() is a Pandas DataFrame method that generates summary statistics of your dataset’s numeric columns (by default).
# It summarizes numerical data showing count, mean, min, max, and other key metrics

# %% [markdown]
# ### 6.3 Number of Columns and Rows

# %%
print("\n Number of Rows and columns: ",df.shape)
# Out:
#  Number of Rows and columns:  (3900, 18)

# %% [markdown]
# df.shape is a Pandas DataFrame attribute that returns a tuple representing the dimensions (number of rows and columns) of the DataFrame.

# %% [markdown]
# ### 6.4 Identify the data types

# %%
print("Datatypes:")
df.dtypes
# Out:
# Datatypes:
# Customer ID                 int64
# Age                         int64
# Gender                     object
# Item Purchased             object
# Category                   object
# Purchase Amount (USD)       int64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Payment Method             object
# Frequency of Purchases     object
# dtype: object

# %% [markdown]
# df.dtypes is a Pandas DataFrame attribute that shows the data type (dtype) of each column in the DataFrame.

# %% [markdown]
# Here we can see that most datatypes are incorrect
# it is identifies as object.

# %%
df.columns = df.columns.str.upper()
df
# Out:
#       CUSTOMER ID  AGE  GENDER ITEM PURCHASED     CATEGORY  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       PURCHASE AMOUNT (USD)       LOCATION SIZE      COLOR  SEASON  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# The columns are changes its style for better understanding

# %% [markdown]
# ## 7️⃣. DATA PRE-PROCESSING:
#     7.1 Handling missing values
#     7.2 Removing duplicates
#     7.3 Correcting data types
#     7.4 Creating derived columns

# %% [markdown]
# ### 7.1  Handling Missing Values

# %%
df.isnull().sum()
# Out:
# CUSTOMER ID               0
# AGE                       0
# GENDER                    0
# ITEM PURCHASED            0
# CATEGORY                  0
# PURCHASE AMOUNT (USD)     0
# LOCATION                  0
# SIZE                      0
# COLOR                     0
# SEASON                    0
# REVIEW RATING             0
# SUBSCRIPTION STATUS       0
# SHIPPING TYPE             0
# DISCOUNT APPLIED          0
# PROMO CODE USED           0
# PREVIOUS PURCHASES        0
# PAYMENT METHOD            0
# FREQUENCY OF PURCHASES    0
# dtype: int64

# %% [markdown]
# df.isnull().sum() is used to find the total number of missing (null/NaN) values in each column of a DataFrame.

# %% [markdown]
# Here no Missing Values are founded

# %% [markdown]
# ### 7.2  Removing Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# df.duplicated().sum() is used to find the total number of duplicate rows in a DataFrame.

# %% [markdown]
# Here No duplicates are founded

# %% [markdown]
# ### 7.3  Correcting Data Types

# %%
#Gender
df['GENDER'] = df['GENDER'].astype('category')

#Item purchased
df['ITEM PURCHASED'] = df['ITEM PURCHASED'].astype(str)

#Category
df['CATEGORY'] = df['CATEGORY'].astype('category')

#Location
df['LOCATION'] = df['LOCATION'].astype(str)

#Size
df['SIZE'] = df['SIZE'].astype('category')

#Color
df['COLOR'] = df['COLOR'].astype('category')

#Season
df['SEASON'] = df['SEASON'].astype('category')

#Subscription Status
df['SUBSCRIPTION STATUS'] = df['SUBSCRIPTION STATUS'].astype('category')

#Shipping Type
df['SHIPPING TYPE'] = df['SHIPPING TYPE'].astype('category')

#Discount Applied
df['DISCOUNT APLLIED'] = df['DISCOUNT APPLIED'].map({'Yes': True,'No': False})

#Promo code used
df['PROMO CODE USED'] = df['PROMO CODE USED'].map({'Yes':True,'No':False})

#Payment method
df['PAYMENT METHOD'] = df['PAYMENT METHOD'].astype('category')

#Frequency of Purchase
df['FREQUENCY OF PURCHASES'] = df['FREQUENCY OF PURCHASES'].astype('category')

# %% [markdown]
# Here converting columns to their most appropriate data types, which:
#
#     Improves memory efficiency
#     Speeds up data operations
#     Makes the dataset more accurate and consistent

# %%
print("DataType corrected Succesfully!!")
df.dtypes
# Out:
# DataType corrected Succesfully!!
# CUSTOMER ID                  int64
# AGE                          int64
# GENDER                    category
# ITEM PURCHASED              object
# CATEGORY                  category
# PURCHASE AMOUNT (USD)        int64
# LOCATION                    object
# SIZE                      category
# COLOR                     category
# SEASON                    category
# REVIEW RATING              float64
# SUBSCRIPTION STATUS       category
# SHIPPING TYPE             category
# DISCOUNT APPLIED            object
# PROMO CODE USED               bool
# PREVIOUS PURCHASES           int64
# PAYMENT METHOD            category
# FREQUENCY OF PURCHASES    category
# DISCOUNT APLLIED              bool
# dtype: object

# %% [markdown]
# ### 7.4  Creating Derived Columns
#     7.4.1 Age Group
#     7.4.2 Customer Segment based on purchased amount

# %%
# Age Group
df['AGE GROUP'] = pd.cut(
    df['AGE'],bins = [0,18,30,45,60,100],
    labels= ['Teen','Young Adult','Adult','Middle Age', 'Senior']
)
Age_seg = df['AGE GROUP']

# %% [markdown]
#     Helps in segmentation (e.g., marketing by age group)
#     Makes charts and summaries more readable
#     Allows grouped statistical analysis.

# %%
# customer classification
df['CUSTOMER_SEGMENT'] = pd.cut(
    df['PURCHASE AMOUNT (USD)'],
    bins=[0, 45, 75, 90],
    labels=['Budget Buyer', 'Regular Buyer', 'Premium Buyer']
)

# %% [markdown]
#     Helps in customer segmentation and target marketing
#     Enables deeper behavioral analysis (e.g., average purchase by segment)
#     Makes visualizations and reports clearer (pie charts, bar plots).

# %%
df.head()
# Out:
#    CUSTOMER ID  AGE GENDER ITEM PURCHASED  CATEGORY  PURCHASE AMOUNT (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         LOCATION SIZE      COLOR  SEASON  ...  SUBSCRIPTION STATUS  \
# 0       Kentucky    L       Gray  Winter  ...                  Yes
# 1          Maine    L     Maroon  Winter  ...                  Yes
# 2  Massachusetts    S     Maroon  Spring  ...                  Yes
# 3   Rhode Island    M     Maroon  Spring  ...                  Yes
# 4         Oregon    M  Turquoise  Spring  ...                  Yes
#
#    SHIPPING TYPE DISCOUNT APPLIED PROMO CODE USED  PREVIOUS PURCHASES  \
# ...

# %% [markdown]
# ##  8️⃣. EXPLORATORY DATA ANALYSIS (EDA) :
#     8.1 Filtering data
#     8.2 Aggregating data

# %% [markdown]
# ### 8.1 Filtering Data

# %% [markdown]
# Filtering means selecting rows in a DataFrame based on specific conditions.

# %%
#Filter by Gender
df_male = df[df['GENDER'] == 'Male']
df_male
# Out:
#       CUSTOMER ID  AGE GENDER ITEM PURCHASED     CATEGORY  \
# 0               1   55   Male         Blouse     Clothing
# 1               2   19   Male        Sweater     Clothing
# 2               3   50   Male          Jeans     Clothing
# 3               4   21   Male        Sandals     Footwear
# 4               5   45   Male         Blouse     Clothing
# ...           ...  ...    ...            ...          ...
# 2647         2648   60   Male          Shoes     Footwear
# 2648         2649   51   Male          Pants     Clothing
# 2649         2650   23   Male         Gloves  Accessories
# 2650         2651   20   Male          Socks     Clothing
# 2651         2652   51   Male       Sneakers     Footwear
#
#       PURCHASE AMOUNT (USD)        LOCATION SIZE      COLOR  SEASON  ...  \
# 0                        53        Kentucky    L       Gray  Winter  ...
# 1                        64           Maine    L     Maroon  Winter  ...
# ...

# %% [markdown]
#     Compare average spending by gender
#     Analyze purchase behavior
#     Create gender-based visualizations

# %% [markdown]
# ### 8.2 Aggregating Data

# %% [markdown]
# Combining or summarizing multiple rows of data into a single value based on some rule (like sum, average, count, max, or min).

# %%
# Average purchase by gender
gender_purchase = df.groupby('GENDER')['PURCHASE AMOUNT (USD)'].sum()
gender_purchase
# Out:
# C:\Users\Nasweeba\AppData\Local\Temp\ipykernel_26684\2405617028.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gender_purchase = df.groupby('GENDER')['PURCHASE AMOUNT (USD)'].sum()
# GENDER
# Female     75191
# Male      157890
# Name: PURCHASE AMOUNT (USD), dtype: int64

# %% [markdown]
#     Helps compare average spending between genders
#     Useful for marketing segmentation (e.g., females spend slightly more on average)
#     Easy way to summarize grouped data for reports or dashboards.

# %%
# Total Previous Purchase by Category
category_purchase = df.groupby('CATEGORY')['PREVIOUS PURCHASES'].sum()
category_purchase
# Out:
# C:\Users\Nasweeba\AppData\Local\Temp\ipykernel_26684\2930309599.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   category_purchase = df.groupby('CATEGORY')['PREVIOUS PURCHASES'].sum()
# CATEGORY
# Accessories    31900
# Clothing       43771
# Footwear       15114
# Outerwear       8086
# Name: PREVIOUS PURCHASES, dtype: int64

# %% [markdown]
#     we get the summary of total spending per product category
#     Identifying which category sells the most
#     Analyzing revenue contribution
#     Business decision-making (e.g., focus more on high-earning categories)

# %%
#Number of Customers in Each age group
Customer_ageGroup = df['AGE GROUP'].value_counts()
Customer_ageGroup
# Out:
# AGE GROUP
# Middle Age     1135
# Adult          1093
# Young Adult     880
# Senior          723
# Teen             69
# Name: count, dtype: int64

# %% [markdown]
#     Quickly shows the distribution of customers across age categories
#     Helps identify which age group is dominant
#     Useful for marketing segmentation and visualizations.

# %%
# multiple columns
purchase_trend = df.groupby(['GENDER', 'CATEGORY'])['PURCHASE AMOUNT (USD)'].mean().reset_index()
purchase_trend
# Out:
# C:\Users\Nasweeba\AppData\Local\Temp\ipykernel_26684\1072039164.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   purchase_trend = df.groupby(['GENDER', 'CATEGORY'])['PURCHASE AMOUNT (USD)'].mean().reset_index()
#    GENDER     CATEGORY  PURCHASE AMOUNT (USD)
# 0  Female  Accessories              60.762755
# 1  Female     Clothing              60.496403
# 2  Female     Footwear              59.472362
# 3  Female    Outerwear              58.425743
# 4    Male  Accessories              59.411557
# 5    Male     Clothing              59.803556
# 6    Male     Footwear              60.645000
# 7    Male    Outerwear              56.605381

# %% [markdown]
#     Shows purchase trends by both gender and category
#     Helps in targeted marketing and category-specific promotions
#     Common step in sales and customer analytics.

# %% [markdown]
# Here all the Preprocessing of the data is Completed
# Data is ready for Analysis and Visualization.

# %% [markdown]
# ## 9️⃣. VISUALIZATION :

# %% [markdown]
# ### 9.1. PURCHASE TREND BY GENDER ACROSS CATEGORIES
# LINEPLOT

# %%
purchase_trend = df.groupby(['GENDER', 'CATEGORY'])['PURCHASE AMOUNT (USD)'].sum().reset_index()

plt.figure(figsize=(8,6))
sns.lineplot(
    data=purchase_trend,
    x='CATEGORY',
    y='PURCHASE AMOUNT (USD)',
    hue='GENDER',
    marker='o'
)

plt.title("Purchase Trend by Gender Across Categories", fontsize=14)
plt.xlabel("Category")
plt.ylabel("Avg Purchase Amount (USD)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Nasweeba\AppData\Local\Temp\ipykernel_26684\3280223749.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   purchase_trend = df.groupby(['GENDER', 'CATEGORY'])['PURCHASE AMOUNT (USD)'].sum().reset_index()

# %% [markdown]
# #### This Line Plot shows :-
#     Males spend more than females across all categories.
#     Clothing is the highest-spending category for both genders.
#     Spending drops sharply for Footwear and even more for Outerwear.
#     Female spending is more stable, while male spending shows stronger peaks and drops.
#     Category preferences differ by gender, suggesting the need for targeted product and marketing strategies.

# %% [markdown]
# ### 9.2. AVERAGE PURCHASE AMOUNT BY AGE GROUP
# LINEPLOT

# %%
age_order = ['Teen', 'Young Adult', 'Adult', 'Middle Age', 'Senior']

# Calculate average purchase amount for each age group
age_group_purchase = (
    df.groupby('AGE GROUP')['PURCHASE AMOUNT (USD)'].mean()
      .reindex(age_order)
      .reset_index()
)

plt.figure(figsize=(10,6))
sns.lineplot(data=age_group_purchase, x='AGE GROUP', y='PURCHASE AMOUNT (USD)', marker='o')
plt.title('Average Purchase Amount by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Average Purchase Amount (USD)')
plt.grid(True)
plt.show()
Customer_ageGroup
# Out:
# C:\Users\Nasweeba\AppData\Local\Temp\ipykernel_26684\204446009.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('AGE GROUP')['PURCHASE AMOUNT (USD)'].mean()
# AGE GROUP
# Middle Age     1135
# Adult          1093
# Young Adult     880
# Senior          723
# Teen             69
# Name: count, dtype: int64

# %% [markdown]
# #### This Line Plot show:-
#     Teens show the widest spread in spending, indicating inconsistent purchase behavior.
#     Young Adults have moderate spending with some high-value outliers.
#     Adults maintain stable, mid-range purchase amounts with fewer extremes.
#     Middle Age customers show controlled, consistent spending with narrow variability.
#     Seniors generally spend less with very low variation in purchase amounts.

# %% [markdown]
# ### 9.3. PURCHASE AMOUNT DISTRIBUTION BY GENDER
# PIE CHART

# %%
# Calculate total purchase amount for each gender
gender_purchase = df.groupby('GENDER')['PURCHASE AMOUNT (USD)'].sum()

plt.figure(figsize=(12,6))

# Pie chart
patches, texts, autotexts = plt.pie(
    gender_purchase,
    autopct='%1.1f%%',
    startangle=90
)

# Add legend
plt.legend(patches, gender_purchase.index, title="Gender", loc="best")

plt.title('Purchase Amount Distribution by Gender')
plt.show()
gender_purchase
# Out:
# C:\Users\Nasweeba\AppData\Local\Temp\ipykernel_26684\358840438.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gender_purchase = df.groupby('GENDER')['PURCHASE AMOUNT (USD)'].sum()
# GENDER
# Female     75191
# Male      157890
# Name: PURCHASE AMOUNT (USD), dtype: int64

# %% [markdown]
# #### This Pie Chart show:-
#     Male customers dominate overall spending, contributing nearly twice as much as female customers.
#     The 67.7% share indicates stronger purchase intensity or higher-value transactions among male customers.
#     The 32.3% share from females suggests either fewer purchases or lower average purchase amounts.
#     The imbalance hints that marketing strategies targeting male shoppers may currently be more effective.
#     It also suggests an opportunity to develop campaigns to increase engagement and spending among female customers.

# %% [markdown]
# ### 9.4. AVERAGE PURCHASE AMOUNT BY SEASON
# BARPLOT

# %%
# Calculate average purchase amount for each season
season_purchase = df.groupby('SEASON')['PURCHASE AMOUNT (USD)'].mean().reset_index()

plt.figure(figsize=(10,6))
sns.barplot(data=season_purchase, x='SEASON', y='PURCHASE AMOUNT (USD)')

plt.title('Average Purchase Amount by Season')
plt.xlabel('Season')
plt.ylabel('Average Purchase Amount (USD)')
plt.show()
# Out:
# C:\Users\Nasweeba\AppData\Local\Temp\ipykernel_26684\2567419194.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   season_purchase = df.groupby('SEASON')['PURCHASE AMOUNT (USD)'].mean().reset_index()

# %% [markdown]
# #### This Bar Plot shows:-
#     Fall has the highest average purchase amount, indicating stronger buying behavior during this season.
#     Spring and Summer show slightly lower purchase averages, suggesting relatively reduced spending in these periods.
#     Winter purchases are moderately high, close to Fall, showing steady consumer demand during colder months.
#     Overall, seasonal variation is small, indicating consistent spending across all seasons with only slight peaks.

# %% [markdown]
# ### 9.5. ITEM PURCHASED BY SEASON AND CATEGORY
# COUNTPLOT

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='SEASON', hue='CATEGORY')

plt.title("Items Purchased by Season and Category")
plt.xlabel("Season")
plt.ylabel("Number of Items Purchased")
plt.legend(title="Category")
plt.show()

# %% [markdown]
# #### This Count plot show:-
#     Clothing is the top-purchased category in all seasons, consistently outperforming others.
#     Accessories are the second most purchased across every season with stable demand.
#     Footwear demand peaks in Spring and Summer, slightly dropping in Fall and Winter.
#     Outerwear is the least purchased category, with purchases dipping in Summer and rising slightly in Fall/Winter.

# %% [markdown]
# ### 9.6. TOP 10 LOCATION - AVERAGE PURCHASE AMOUNT BY CATEGORY
# HEATMAP

# %%
# Top 10 locations
top_locations = (
    df.groupby('LOCATION')['PURCHASE AMOUNT (USD)']
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .index
)

df_top = df[df['LOCATION'].isin(top_locations)]

pivot = df_top.pivot_table(
    values='PURCHASE AMOUNT (USD)',
    index='LOCATION',
    columns='CATEGORY',
    aggfunc='mean'
)

plt.figure(figsize=(10,6))
sns.heatmap(pivot, annot=True, cmap='Blues', fmt=".1f")

plt.title('Top 10 Locations - Average Purchase Amount by Category')
plt.xlabel('Category')
plt.ylabel('Location')
plt.show()
# Out:
# C:\Users\Nasweeba\AppData\Local\Temp\ipykernel_26684\2781571164.py:12: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = df_top.pivot_table(

# %% [markdown]
# #### This HeatMap shows:-
#     Illinois shows the highest purchase amounts, especially for Outerwear (73.8) and Accessories (68.7).
#     Nevada has strong spending in Accessories and Clothing, but very low Outerwear spending (31.2).
#     Idaho, Nebraska, and North Dakota show consistent above-average spending, especially in Outerwear.
#     Montana has the lowest Footwear spending (46.2).
#     Overall, Outerwear spending varies the most, while Clothing shows stable demand across locations.

# %% [markdown]
# ### 9.7. DISTRIBUTION OF PREVIOUS PURCHASES BY CATEGORY
# HISTPLOT

# %%
plt.figure(figsize=(10,6))
sns.histplot(
    data=df,
    x="PREVIOUS PURCHASES",
    hue="CATEGORY",
    kde=True,
    multiple="stack"   # or "layer" if you prefer overlapping curves
)

plt.title("Distribution of Previous purchases by Category")
plt.xlabel("Previous Purchases")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
category_purchase
# Out:
# CATEGORY
# Accessories    31900
# Clothing       43771
# Footwear       15114
# Outerwear       8086
# Name: PREVIOUS PURCHASES, dtype: int64

# %% [markdown]
# #### This Hist plot shows:-
#     Clothing is the most purchased category.
#     Accessories come second with steady demand.
#     Footwear is moderately purchased.
#     Outerwear has the lowest purchase frequency.

# %% [markdown]
# ### 9.8. PURCHASE AMOUNT BY CATEGORY AND SIZE
# BARPLOT

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

sns.barplot(
    data=df,
    x="CATEGORY",
    y="PURCHASE AMOUNT (USD)",
    hue="SIZE"
)

plt.title("Purchase Amount by Category and Size")
plt.xlabel("Category")
plt.ylabel("Total Purchase Amount")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### This barplot shows:-
#     Clothing and Footwear show the highest purchase amounts across sizes, especially for S and XL sizes.
#     Accessories and Outerwear have relatively lower purchase amounts compared to other categories.
#     Size S and XL consistently perform better than L and M across most categories.
#     Size L tends to have the lowest purchase amounts in multiple categories.

# %% [markdown]
# ### 9.9. PURCHASE AMOUNT DISTRIBUTION BY SUBSCRIPTION STATUS
# PIE CHART

# %%
# Aggregate purchase amount by subscription status
sub_amount = df.groupby("SUBSCRIPTION STATUS")["PURCHASE AMOUNT (USD)"].sum()

# Plot pie chart
plt.figure(figsize=(8,7))
plt.pie(sub_amount, 
        labels=sub_amount.index, 
        autopct='%1.1f%%', 
        startangle=140)
plt.title("Purchase Amount Distribution by Subscription Status")
plt.legend(title="Subscription Status", loc="upper right")
plt.show()
# Out:
# C:\Users\Nasweeba\AppData\Local\Temp\ipykernel_26684\2252941102.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sub_amount = df.groupby("SUBSCRIPTION STATUS")["PURCHASE AMOUNT (USD)"].sum()

# %% [markdown]
# #### This Pie Chart shows:-
#     A large majority (73.1%) of the total purchase amount comes from non-subscribed customers.
#     Only 26.9% of purchase amount comes from subscribed customers.
#     This indicates that most revenue is driven by customers who are not subscribed
#     The business may need to improve subscription value or run engagement campaigns to increase purchases among subscribers.

# %% [markdown]
# ### 9.10. PURCHASE AMOUNT BY CATEGORY WITH DISCOUNT APPLIED
# BOXPLOT

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    data=df,
    x="CATEGORY",
    y="PURCHASE AMOUNT (USD)",
    hue="DISCOUNT APPLIED"
)

plt.title("Purchase Amount by Category with Discount Applied")
plt.xlabel("Category")
plt.ylabel("Purchase Amount (USD)")
plt.legend(title="Discount Applied")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### This Box plot shows:-
#     Purchase amounts are similar across all categories whether a discount is applied or not—no major shift in medians.
#     Discounted purchases show slightly lower median in Outerwear but similar in other categories.
#     Variability (spread) is almost identical for “Yes” and “No” across all categories.
#     No category shows a strong discount-driven change in spending behavior.
#     Overall: discounts do not significantly change purchase amounts in any category.

# %% [markdown]
# ## 1️⃣0️⃣. OVERALL INSIGHTS:-
# 1.  Males spend more across all categories, while females show steadier spending, indicating clear gender-based purchasing preferences.
# 2.  Teens show the most unpredictable spending while older groups—especially Seniors—maintain low, stable purchase amounts, highlighting a clear
#     decline in variability with age.
# 3.  Male customers drive significantly higher overall spending than females, revealing a strong gender imbalance and a clear opportunity to boost
#     engagement among female shoppers.
# 4.  Seasonal spending remains mostly consistent, with only a slight peak in Fall and steady demand across the other seasons.
# 5.  Clothing leads purchases across all seasons, while Accessories stay steady, Footwear varies slightly, and Outerwear remains consistently the least
#     bought.
# 6.  Illinois leads overall spending with strong Outerwear and Accessories purchases, while other states show mixed patterns and Clothing remains
#     consistently stable across locations.
# 7.  Clothing is the most frequently purchased category, followed by Accessories, while Footwear is moderate and Outerwear is the least purchased.
# 8.  Size S and XL drive the highest purchase amounts across categories, while Size L consistently performs the weakest
# 9.  Most revenue comes from non-subscribed customers, highlighting a clear need to improve subscription value and boost subscriber engagement.
# 10. Discounts have little to no impact on purchase amounts across all categories, showing no meaningful change in customer spending behavior.

# %% [markdown]
# ## 1️⃣1️⃣. CONCLUSION:-
# Customers show stable spending patterns across seasons, locations, and discount conditions, with strong dominance in Clothing purchases and higher spending from males, teens, and non-subscribed buyers; overall, the data reveals clear demographic and category-based preferences but no meaningful impact from discounts, highlighting opportunities to enhance subscription value and target lower-performing segments like females, seniors, Outerwear, and Size L buyers.

# %% [markdown]
# ## 1️⃣2️⃣. FUTURE RECOMMENDATION:-
# 1. Use gender-specific marketing to boost female engagement while maintaining male spending.
# 2. Apply age-focused promotions—trend deals for teens, value bundles for adults and seniors.
# 3. Strengthen Fall-season campaigns and keep steady promotions in other seasons.
# 4. Prioritize Clothing and Accessories inventory; limit Outerwear stock.
# 5. Adjust inventory and marketing by location to match state-wise demand.
# 6. Increase availability of high-demand sizes (S & XL) and review issues with size L.
# 7. Improve subscription benefits to convert non-subscribed customers.
# 8. Reduce reliance on discounts since they don’t significantly change spending behavior.
